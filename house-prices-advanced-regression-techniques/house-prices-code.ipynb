# %% [markdown]
# # House Prices: Advanced Regression Techniques

# %% [markdown]
# ## Problem Statment

# %% [markdown]
# ## Executive Summary

# %% [markdown]
# ## Datasets Description

# %% [markdown]
# ## Data Import and Cleaning

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score, cross_val_predict, KFold
from sklearn import metrics
from sklearn.preprocessing import StandardScaler

# %matplotlib inline

# %%
file_house_prices = pd.read_csv('./train.csv', index_col='Id', delimiter=',', header=0)
file_house_test = pd.read_csv('./test.csv', index_col='Id', delimiter=',', header=0)

house_prices = pd.DataFrame(file_house_prices)
house_test = pd.DataFrame(file_house_test)

# housing_train.info
# housing_test.info

# %%
house_test.head()
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1462          20       RL         81.0    14267   Pave   NaN      IR1
# 1463          60       RL         74.0    13830   Pave   NaN      IR1
# 1464          60       RL         78.0     9978   Pave   NaN      IR1
# 1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC  Fence  \
# Id                                    ...
# 1461         Lvl    AllPub    Inside  ...         120        0    NaN  MnPrv
# 1462         Lvl    AllPub    Corner  ...           0        0    NaN    NaN
# 1463         Lvl    AllPub    Inside  ...           0        0    NaN  MnPrv
# 1464         Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 1465         HLS    AllPub    Inside  ...         144        0    NaN    NaN
#
#      MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# Id
# 1461         NaN       0       6    2010        WD         Normal
# 1462        Gar2   12500       6    2010        WD         Normal
# 1463         NaN       0       3    2010        WD         Normal
# 1464         NaN       0       6    2010        WD         Normal
# 1465         NaN       0       1    2010        WD         Normal
#
# [5 rows x 79 columns]

# %%
house_prices.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 3          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 4          Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 5          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
#
#    MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1        0      2    2008        WD         Normal     208500
# 2        0      5    2007        WD         Normal     181500
# 3        0      9    2008        WD         Normal     223500
# 4        0      2    2006        WD        Abnorml     140000
# 5        0     12    2008        WD         Normal     250000
#
# [5 rows x 80 columns]

# %%
house_prices.dtypes
# Out:
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
# BsmtQual          object
#                   ...
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# KitchenQual       object
# TotRmsAbvGrd       int64
# Functional        object
# Fireplaces         int64
# FireplaceQu       object
# GarageType        object
# GarageYrBlt      float64
# GarageFinish      object
# GarageCars         int64
# GarageArea         int64
# GarageQual        object
# GarageCond        object
# PavedDrive        object
# WoodDeckSF         int64
# OpenPorchSF        int64
# EnclosedPorch      int64
# 3SsnPorch          int64
# ScreenPorch        int64
# PoolArea           int64
# PoolQC            object
# Fence             object
# MiscFeature       object
# MiscVal            int64
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 80, dtype: object

# %%
house_prices.describe()
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1201.000000    1460.000000  1460.000000  1460.000000
# mean     56.897260    70.049958   10516.828082     6.099315     5.575342
# std      42.300571    24.284752    9981.264932     1.382997     1.112799
# min      20.000000    21.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    59.000000    7553.500000     5.000000     5.000000
# 50%      50.000000    69.000000    9478.500000     6.000000     5.000000
# 75%      70.000000    80.000000   11601.500000     7.000000     6.000000
# max     190.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...  \
# count  1460.000000   1460.000000  1452.000000  1460.000000  1460.000000  ...
# mean   1971.267808   1984.865753   103.685262   443.639726    46.549315  ...
# std      30.202904     20.645407   181.066207   456.098091   161.319273  ...
# min    1872.000000   1950.000000     0.000000     0.000000     0.000000  ...
# 25%    1954.000000   1967.000000     0.000000     0.000000     0.000000  ...
# 50%    1973.000000   1994.000000     0.000000   383.500000     0.000000  ...
# 75%    2000.000000   2004.000000   166.000000   712.250000     0.000000  ...
# max    2010.000000   2010.000000  1600.000000  5644.000000  1474.000000  ...
#
#         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean     94.244521    46.660274      21.954110     3.409589    15.060959
# std     125.338794    66.256028      61.119149    29.317331    55.757415
# min       0.000000     0.000000       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000       0.000000     0.000000     0.000000
# 50%       0.000000    25.000000       0.000000     0.000000     0.000000
# 75%     168.000000    68.000000       0.000000     0.000000     0.000000
# max     857.000000   547.000000     552.000000   508.000000   480.000000
#
#           PoolArea       MiscVal       MoSold       YrSold      SalePrice
# count  1460.000000   1460.000000  1460.000000  1460.000000    1460.000000
# mean      2.758904     43.489041     6.321918  2007.815753  180921.195890
# std      40.177307    496.123024     2.703626     1.328095   79442.502883
# min       0.000000      0.000000     1.000000  2006.000000   34900.000000
# 25%       0.000000      0.000000     5.000000  2007.000000  129975.000000
# 50%       0.000000      0.000000     6.000000  2008.000000  163000.000000
# 75%       0.000000      0.000000     8.000000  2009.000000  214000.000000
# max     738.000000  15500.000000    12.000000  2010.000000  755000.000000
#
# [8 rows x 37 columns]

# %%
house_prices.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond',
#        'PavedDrive', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'PoolQC', 'Fence', 'MiscFeature', 'MiscVal',
#        'MoSold', 'YrSold', 'SaleType', 'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
house_test.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond',
#        'PavedDrive', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'PoolQC', 'Fence', 'MiscFeature', 'MiscVal',
#        'MoSold', 'YrSold', 'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
len(house_prices.columns)
# Out:
# 80

# %%
house_prices.shape
# Out:
# (1460, 80)

# %%
#the data frame for the features

df = house_prices.drop(labels='SalePrice', axis=1)
df
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# 6             50       RL         85.0    14115   Pave   NaN      IR1
# 7             20       RL         75.0    10084   Pave   NaN      Reg
# 8             60       RL          NaN    10382   Pave   NaN      IR1
# 9             50       RM         51.0     6120   Pave   NaN      Reg
# 10           190       RL         50.0     7420   Pave   NaN      Reg
# 11            20       RL         70.0    11200   Pave   NaN      Reg
# 12            60       RL         85.0    11924   Pave   NaN      IR1
# 13            20       RL          NaN    12968   Pave   NaN      IR2
# 14            20       RL         91.0    10652   Pave   NaN      IR1
# 15            20       RL          NaN    10920   Pave   NaN      IR1
# 16            45       RM         51.0     6120   Pave   NaN      Reg
# 17            20       RL          NaN    11241   Pave   NaN      IR1
# 18            90       RL         72.0    10791   Pave   NaN      Reg
# 19            20       RL         66.0    13695   Pave   NaN      Reg
# 20            20       RL         70.0     7560   Pave   NaN      Reg
# 21            60       RL        101.0    14215   Pave   NaN      IR1
# 22            45       RM         57.0     7449   Pave  Grvl      Reg
# 23            20       RL         75.0     9742   Pave   NaN      Reg
# 24           120       RM         44.0     4224   Pave   NaN      Reg
# 25            20       RL          NaN     8246   Pave   NaN      IR1
# 26            20       RL        110.0    14230   Pave   NaN      Reg
# 27            20       RL         60.0     7200   Pave   NaN      Reg
# 28            20       RL         98.0    11478   Pave   NaN      Reg
# 29            20       RL         47.0    16321   Pave   NaN      IR1
# 30            30       RM         60.0     6324   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1431          60       RL         60.0    21930   Pave   NaN      IR3
# 1432         120       RL          NaN     4928   Pave   NaN      IR1
# 1433          30       RL         60.0    10800   Pave  Grvl      Reg
# 1434          60       RL         93.0    10261   Pave   NaN      IR1
# 1435          20       RL         80.0    17400   Pave   NaN      Reg
# 1436          20       RL         80.0     8400   Pave   NaN      Reg
# 1437          20       RL         60.0     9000   Pave   NaN      Reg
# 1438          20       RL         96.0    12444   Pave   NaN      Reg
# 1439          20       RM         90.0     7407   Pave   NaN      Reg
# 1440          60       RL         80.0    11584   Pave   NaN      Reg
# 1441          70       RL         79.0    11526   Pave   NaN      IR1
# 1442         120       RM          NaN     4426   Pave   NaN      Reg
# 1443          60       FV         85.0    11003   Pave   NaN      Reg
# 1444          30       RL          NaN     8854   Pave   NaN      Reg
# 1445          20       RL         63.0     8500   Pave   NaN      Reg
# 1446          85       RL         70.0     8400   Pave   NaN      Reg
# 1447          20       RL          NaN    26142   Pave   NaN      IR1
# 1448          60       RL         80.0    10000   Pave   NaN      Reg
# 1449          50       RL         70.0    11767   Pave   NaN      Reg
# 1450         180       RM         21.0     1533   Pave   NaN      Reg
# 1451          90       RL         60.0     9000   Pave   NaN      Reg
# 1452          20       RL         78.0     9262   Pave   NaN      Reg
# 1453         180       RM         35.0     3675   Pave   NaN      Reg
# 1454          20       RL         90.0    17217   Pave   NaN      Reg
# 1455          20       FV         62.0     7500   Pave  Pave      Reg
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC  Fence  \
# Id                                    ...
# 1            Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 2            Lvl    AllPub       FR2  ...           0        0    NaN    NaN
# 3            Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 4            Lvl    AllPub    Corner  ...           0        0    NaN    NaN
# 5            Lvl    AllPub       FR2  ...           0        0    NaN    NaN
# 6            Lvl    AllPub    Inside  ...           0        0    NaN  MnPrv
# 7            Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 8            Lvl    AllPub    Corner  ...           0        0    NaN    NaN
# 9            Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 10           Lvl    AllPub    Corner  ...           0        0    NaN    NaN
# 11           Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 12           Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 13           Lvl    AllPub    Inside  ...         176        0    NaN    NaN
# 14           Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 15           Lvl    AllPub    Corner  ...           0        0    NaN   GdWo
# 16           Lvl    AllPub    Corner  ...           0        0    NaN  GdPrv
# 17           Lvl    AllPub   CulDSac  ...           0        0    NaN    NaN
# 18           Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 19           Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 20           Lvl    AllPub    Inside  ...           0        0    NaN  MnPrv
# 21           Lvl    AllPub    Corner  ...           0        0    NaN    NaN
# 22           Bnk    AllPub    Inside  ...           0        0    NaN  GdPrv
# 23           Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 24           Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 25           Lvl    AllPub    Inside  ...           0        0    NaN  MnPrv
# 26           Lvl    AllPub    Corner  ...           0        0    NaN    NaN
# 27           Lvl    AllPub    Corner  ...           0        0    NaN    NaN
# 28           Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 29           Lvl    AllPub   CulDSac  ...           0        0    NaN    NaN
# 30           Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# ...          ...       ...       ...  ...         ...      ...    ...    ...
# 1431         Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 1432         Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 1433         Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 1434         Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 1435         Low    AllPub    Inside  ...           0        0    NaN    NaN
# 1436         Lvl    AllPub    Inside  ...           0        0    NaN  GdPrv
# 1437         Lvl    AllPub       FR2  ...           0        0    NaN   GdWo
# 1438         Lvl    AllPub       FR2  ...           0        0    NaN    NaN
# 1439         Lvl    AllPub    Inside  ...           0        0    NaN  MnPrv
# 1440         Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 1441         Bnk    AllPub    Inside  ...           0        0    NaN    NaN
# 1442         Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 1443         Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 1444         Lvl    AllPub    Inside  ...          40        0    NaN    NaN
# 1445         Lvl    AllPub       FR2  ...           0        0    NaN    NaN
# 1446         Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 1447         Lvl    AllPub   CulDSac  ...           0        0    NaN    NaN
# 1448         Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 1449         Lvl    AllPub    Inside  ...           0        0    NaN   GdWo
# 1450         Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 1451         Lvl    AllPub       FR2  ...           0        0    NaN    NaN
# 1452         Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 1453         Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 1454         Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 1455         Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 1456         Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 1457         Lvl    AllPub    Inside  ...           0        0    NaN  MnPrv
# 1458         Lvl    AllPub    Inside  ...           0        0    NaN  GdPrv
# 1459         Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 1460         Lvl    AllPub    Inside  ...           0        0    NaN    NaN
#
#      MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# Id
# 1            NaN       0       2    2008        WD         Normal
# 2            NaN       0       5    2007        WD         Normal
# 3            NaN       0       9    2008        WD         Normal
# 4            NaN       0       2    2006        WD        Abnorml
# 5            NaN       0      12    2008        WD         Normal
# 6           Shed     700      10    2009        WD         Normal
# 7            NaN       0       8    2007        WD         Normal
# 8           Shed     350      11    2009        WD         Normal
# 9            NaN       0       4    2008        WD        Abnorml
# 10           NaN       0       1    2008        WD         Normal
# 11           NaN       0       2    2008        WD         Normal
# 12           NaN       0       7    2006       New        Partial
# 13           NaN       0       9    2008        WD         Normal
# 14           NaN       0       8    2007       New        Partial
# 15           NaN       0       5    2008        WD         Normal
# 16           NaN       0       7    2007        WD         Normal
# 17          Shed     700       3    2010        WD         Normal
# 18          Shed     500      10    2006        WD         Normal
# 19           NaN       0       6    2008        WD         Normal
# 20           NaN       0       5    2009       COD        Abnorml
# 21           NaN       0      11    2006       New        Partial
# 22           NaN       0       6    2007        WD         Normal
# 23           NaN       0       9    2008        WD         Normal
# 24           NaN       0       6    2007        WD         Normal
# 25           NaN       0       5    2010        WD         Normal
# 26           NaN       0       7    2009        WD         Normal
# 27           NaN       0       5    2010        WD         Normal
# 28           NaN       0       5    2010        WD         Normal
# 29           NaN       0      12    2006        WD         Normal
# 30           NaN       0       5    2008        WD         Normal
# ...          ...     ...     ...     ...       ...            ...
# 1431         NaN       0       7    2006        WD         Normal
# 1432         NaN       0      10    2009        WD         Normal
# 1433         NaN       0       8    2007        WD         Normal
# 1434         NaN       0       5    2008        WD         Normal
# 1435         NaN       0       5    2006        WD         Normal
# 1436         NaN       0       7    2008       COD        Abnorml
# 1437         NaN       0       5    2007        WD         Normal
# 1438         NaN       0      11    2008       New        Partial
# 1439         NaN       0       4    2010        WD         Normal
# 1440         NaN       0      11    2007        WD         Normal
# 1441         NaN       0       9    2008        WD         Normal
# 1442         NaN       0       5    2008        WD         Normal
# 1443         NaN       0       4    2009        WD         Normal
# 1444         NaN       0       5    2009        WD         Normal
# 1445         NaN       0      11    2007        WD         Normal
# 1446         NaN       0       5    2007        WD         Normal
# 1447         NaN       0       4    2010        WD         Normal
# 1448         NaN       0      12    2007        WD         Normal
# 1449         NaN       0       5    2007        WD         Normal
# 1450         NaN       0       8    2006        WD        Abnorml
# 1451         NaN       0       9    2009        WD         Normal
# 1452         NaN       0       5    2009       New        Partial
# 1453         NaN       0       5    2006        WD         Normal
# 1454         NaN       0       7    2006        WD        Abnorml
# 1455         NaN       0      10    2009        WD         Normal
# 1456         NaN       0       8    2007        WD         Normal
# 1457         NaN       0       2    2010        WD         Normal
# 1458        Shed    2500       5    2010        WD         Normal
# 1459         NaN       0       4    2010        WD         Normal
# 1460         NaN       0       6    2008        WD         Normal
#
# [1460 rows x 79 columns]

# %%
#the target (to be predicted)
y = house_prices['SalePrice']
y
# Out:
# Id
# 1       208500
# 2       181500
# 3       223500
# 4       140000
# 5       250000
# 6       143000
# 7       307000
# 8       200000
# 9       129900
# 10      118000
# 11      129500
# 12      345000
# 13      144000
# 14      279500
# 15      157000
# 16      132000
# 17      149000
# 18       90000
# 19      159000
# 20      139000
# 21      325300
# 22      139400
# 23      230000
# 24      129900
# 25      154000
# 26      256300
# 27      134800
# 28      306000
# 29      207500
# 30       68500
#          ...
# 1431    192140
# 1432    143750
# 1433     64500
# 1434    186500
# 1435    160000
# 1436    174000
# 1437    120500
# 1438    394617
# 1439    149700
# 1440    197000
# 1441    191000
# 1442    149300
# 1443    310000
# 1444    121000
# 1445    179600
# 1446    129000
# 1447    157900
# 1448    240000
# 1449    112000
# 1450     92000
# 1451    136000
# 1452    287090
# 1453    145000
# 1454     84500
# 1455    185000
# 1456    175000
# 1457    210000
# 1458    266500
# 1459    142125
# 1460    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %% [markdown]
# ## Plot a heatmap of the correlation matrix

# %%
def correlation_heat_map(df):
    corrs = df.corr()

    # Set the default matplotlib figure size:
    fig, ax = plt.subplots(figsize=(40, 30))

    # Generate a mask for the upper triangle (taken from seaborn example gallery)
    mask = np.zeros_like(corrs, dtype=np.bool)
    mask[np.triu_indices_from(mask)] = True

    # Plot the heatmap with seaborn.
    # Assign the matplotlib axis the function returns. This will let us resize the labels.
    ax = sns.heatmap(corrs, mask=mask)

    # Resize the labels.
    ax.set_xticklabels(ax.xaxis.get_ticklabels(), fontsize=14, rotation=100)
    ax.set_yticklabels(ax.yaxis.get_ticklabels(), fontsize=14, rotation=0)

    # If you put plt.show() at the bottom, it prevents those useless printouts from matplotlib.
    plt.show()


df_with_target = df.copy()
df_with_target['SalePrice'] = y
correlation_heat_map(df_with_target)

# %%
#finding the highest correlated columns with the SalePrice
corr_matrix = house_prices.corr().abs()

# %%
corr_matrix['SalePrice'].sort_values(ascending=False)
# Out:
# SalePrice        1.000000
# OverallQual      0.790982
# GrLivArea        0.708624
# GarageCars       0.640409
# GarageArea       0.623431
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# FullBath         0.560664
# TotRmsAbvGrd     0.533723
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# GarageYrBlt      0.486362
# MasVnrArea       0.477493
# Fireplaces       0.466929
# BsmtFinSF1       0.386420
# LotFrontage      0.351799
# WoodDeckSF       0.324413
# 2ndFlrSF         0.319334
# OpenPorchSF      0.315856
# HalfBath         0.284108
# LotArea          0.263843
# BsmtFullBath     0.227122
# BsmtUnfSF        0.214479
# BedroomAbvGr     0.168213
# KitchenAbvGr     0.135907
# EnclosedPorch    0.128578
# ScreenPorch      0.111447
# PoolArea         0.092404
# MSSubClass       0.084284
# OverallCond      0.077856
# MoSold           0.046432
# 3SsnPorch        0.044584
# YrSold           0.028923
# LowQualFinSF     0.025606
# MiscVal          0.021190
# BsmtHalfBath     0.016844
# BsmtFinSF2       0.011378
# Name: SalePrice, dtype: float64

# %%
#the columns with highest corr
#we will use it in our first regression with train-test split of 0.5

predictors = list(corr_matrix['SalePrice'].sort_values(ascending=False).index[1:11])
predictors
# Out:
# ['OverallQual',
#  'GrLivArea',
#  'GarageCars',
#  'GarageArea',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  'FullBath',
#  'TotRmsAbvGrd',
#  'YearBuilt',
#  'YearRemodAdd']

# %%
X_train, X_test, y_train, y_test = train_test_split(df[predictors], y, 
                                            test_size=0.1, random_state=8)

lr = LinearRegression()

lr.fit(X_train, y_train)

#A simple validation for our model
lr.score(X_test, y_test)
# Out:
# 0.8390424846976372

# %%
#same results can be achieved using the metrics funcion for computing R2. Here it shows what is actually compared.
metrics.r2_score( y_test, lr.predict(X_test))
# Out:
# 0.8390424846976372

# %%
#k-Fold cross-validation for the test set
kf = KFold(n_splits=folds,shuffle=True,random_state=1)
# Perform cross-validation and compute the mean of its results. The resulted R2 is used to compare different models. 
# We caoudl instead just use the whole test set to compute R2, but it would not reflect the performance of our model accurately. 
# The purpose of cross-validation is model checking not model building.
np.mean(cross_val_score(lr, X_test, y_test, cv=kf))
# Out:
# 0.7811985021461925

# %%
#surprisingly when we run the k-fold cross-validation on the whole set, it resutlts in realistic non-overfitting R2.
#It can be called when R2 is nearly =1.
np.mean(cross_val_score(lr, df[predictors], y, cv=kf))
# Out:
# 0.7468723936299566

# %%
#standardise your predictor matrices
ss = StandardScaler()
ss.fit(X_train)
X_train_ss = ss.transform(X_train)
X_test_ss = ss.transform(X_test)
# Out:
# /home/M/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/M/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   after removing the cwd from sys.path.
# /home/M/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   """

# %%
#A model using the scaled data
lr_scaled = LinearRegression()
lr.fit(X_train_ss, y_train)
#A simple validation for our model
lr.score(X_test_ss, y_test)
# Out:
# 0.8390424846976376

# %%
#cross validation on the scaled data
#The results is the same as the non scaled inouts
kf = KFold(n_splits=folds,shuffle=True,random_state=1)
np.mean(cross_val_score(lr_scaled, df[predictors], y, cv=kf))
# Out:
# 0.7468723936299566

# %%
#Gradient Descent

# %%
df_test = house_test[predictors]

# %% [markdown]
# # Final: Predicting the SalePrice for the test data

# %%
df_test[df_test.isnull().any(axis=1)]
# Out:
#       OverallQual  GrLivArea  GarageCars  GarageArea  TotalBsmtSF  1stFlrSF  \
# Id
# 2121            4        896         1.0       280.0          NaN       896
# 2577            5       1828         NaN         NaN        859.0       942
#
#       FullBath  TotRmsAbvGrd  YearBuilt  YearRemodAdd
# Id
# 2121         1             4       1946          1950
# 2577         2             6       1923          1999

# %%
df_test.fillna(0,inplace=True)
# Out:
# /home/M/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:4034: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   downcast=downcast, **kwargs)

# %%
X_train.shape, df_test.shape
# Out:
# ((1314, 10), (1459, 10))

# %%
predctions_test = pd.DataFrame(lr.predict(df_test), index=df_test.index)

# %%
predctions_test.to_csv('./submission.csv', sep=',', encoding='utf-8')

# %%
predctions_test
# Out:
#                  0
# Id
# 1461  6.700323e+07
# 1462  8.362620e+07
# 1463  8.676859e+07
# 1464  8.609543e+07
# 1465  8.264472e+07
# 1466  8.499898e+07
# 1467  7.859607e+07
# 1468  8.035160e+07
# 1469  8.471395e+07
# 1470  6.621371e+07
# 1471  8.558519e+07
# 1472  6.282216e+07
# 1473  6.626195e+07
# 1474  8.080907e+07
# 1475  6.402826e+07
# 1476  1.156878e+08
# 1477  9.435356e+07
# 1478  1.002161e+08
# 1479  1.050776e+08
# 1480  1.421455e+08
# 1481  1.143762e+08
# 1482  8.643110e+07
# 1483  8.438750e+07
# 1484  7.723197e+07
# 1485  7.451999e+07
# 1486  8.839559e+07
# 1487  1.200749e+08
# 1488  9.637549e+07
# 1489  8.075267e+07
# 1490  9.040750e+07
# ...            ...
# 2890  5.543226e+07
# 2891  8.675688e+07
# 2892  5.253991e+07
# 2893  7.748208e+07
# 2894  5.858777e+07
# 2895  1.012117e+08
# 2896  9.719545e+07
# 2897  9.645536e+07
# 2898  9.810318e+07
# 2899  9.124710e+07
# 2900  7.889473e+07
# 2901  9.687974e+07
# 2902  8.740497e+07
# 2903  1.088206e+08
# 2904  1.057596e+08
# 2905  8.112193e+07
# 2906  8.621759e+07
# 2907  7.034300e+07
# 2908  6.550789e+07
# 2909  9.817133e+07
# 2910  5.487819e+07
# 2911  6.639628e+07
# 2912  8.303729e+07
# 2913  6.643967e+07
# 2914  6.579793e+07
# 2915  6.579793e+07
# 2916  6.644028e+07
# 2917  8.022996e+07
# 2918  6.846114e+07
# 2919  9.782533e+07
#
# [1459 rows x 1 columns]
