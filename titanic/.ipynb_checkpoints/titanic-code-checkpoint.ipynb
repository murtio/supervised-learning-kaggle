# %% [markdown]
# # Titanic: Machine Learning from Disaster

# %% [markdown]
# ## Problem Statment

# %% [markdown]
# ## Executive Summary

# %% [markdown]
# ## Datasets Description

# %% [markdown]
# ## Data Import and Cleaning

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score, cross_val_predict, KFold
from sklearn import metrics
from sklearn.preprocessing import StandardScaler

# %matplotlib inline

# %%
file_titanic = pd.read_csv('./train.csv', delimiter=',', header=0)
file_titanic_test = pd.read_csv('./test.csv', delimiter=',', header=0)

titanic = pd.DataFrame(file_titanic)
titanic_test = pd.DataFrame(file_titanic_test)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
titanic.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic_test.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
len(titanic.columns)
# Out:
# 12

# %%
len(titanic_test.columns)
# Out:
# 11

# %%
titanic.shape
# Out:
# (891, 12)

# %%
#the data frame for the features

df = titanic.drop(labels='Survived', axis=1)
df
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# 5              6       3                                   Moran, Mr. James
# 6              7       1                            McCarthy, Mr. Timothy J
# 7              8       3                     Palsson, Master. Gosta Leonard
# 8              9       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9             10       2                Nasser, Mrs. Nicholas (Adele Achem)
# 10            11       3                    Sandstrom, Miss. Marguerite Rut
# ...

# %%
#the target (to be predicted)
y = titanic['Survived']
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
# 5      0
# 6      0
# 7      0
# 8      1
# 9      1
# 10     1
# 11     1
# 12     0
# 13     0
# 14     0
# 15     1
# 16     0
# 17     1
# 18     0
# 19     1
# 20     0
# 21     1
# 22     1
# 23     1
# 24     0
# 25     1
# 26     0
# 27     0
# 28     1
# 29     0
#       ..
# 861    0
# 862    1
# 863    0
# 864    0
# 865    1
# 866    1
# 867    0
# 868    0
# 869    1
# 870    0
# 871    1
# 872    0
# 873    0
# 874    1
# 875    1
# 876    0
# 877    0
# 878    0
# 879    1
# 880    1
# 881    0
# 882    0
# 883    0
# 884    0
# 885    0
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
#concatnate the train dataset with the test dataset in order to apply same preprocessing
df = pd.concat([df, titanic_test], ignore_index=True)
df
# Out:
#       PassengerId  Pclass                                               Name  \
# 0               1       3                            Braund, Mr. Owen Harris
# 1               2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2               3       3                             Heikkinen, Miss. Laina
# 3               4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4               5       3                           Allen, Mr. William Henry
# 5               6       3                                   Moran, Mr. James
# 6               7       1                            McCarthy, Mr. Timothy J
# 7               8       3                     Palsson, Master. Gosta Leonard
# 8               9       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9              10       2                Nasser, Mrs. Nicholas (Adele Achem)
# 10             11       3                    Sandstrom, Miss. Marguerite Rut
# ...

# %%
df.shape
# Out:
# (1309, 11)

# %%
len(titanic_test)+len(titanic)
# Out:
# 1309

# %%
df.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# Numrical:
# 'PassengerId', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare'.
#
# Catogrical:
# 'Survived', 'Pclass', 'Sex','Embarked','Cabin'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 11 columns):
# PassengerId    1309 non-null int64
# Pclass         1309 non-null int64
# Name           1309 non-null object
# Sex            1309 non-null object
# Age            1046 non-null float64
# SibSp          1309 non-null int64
# Parch          1309 non-null int64
# Ticket         1309 non-null object
# Fare           1308 non-null float64
# Cabin          295 non-null object
# Embarked       1307 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 112.6+ KB

# %% [markdown]
# ## Plot a heatmap of the correlation matrix

# %%
def correlation_heat_map(df):
    corrs = df.corr()

    # Set the default matplotlib figure size:
    fig, ax = plt.subplots(figsize=(40, 30))

    # Generate a mask for the upper triangle (taken from seaborn example gallery)
    mask = np.zeros_like(corrs, dtype=np.bool)
    mask[np.triu_indices_from(mask)] = True

    # Plot the heatmap with seaborn.
    # Assign the matplotlib axis the function returns. This will let us resize the labels.
    ax = sns.heatmap(corrs, mask=mask)

    # Resize the labels.
    ax.set_xticklabels(ax.xaxis.get_ticklabels(), fontsize=25, rotation=100)
    ax.set_yticklabels(ax.yaxis.get_ticklabels(), fontsize=25, rotation=0)

    # If you put plt.show() at the bottom, it prevents those useless printouts from matplotlib.
    plt.show()


df_with_target = df.copy()
df_with_target['Survived'] = y
correlation_heat_map(df_with_target)

# %%
#finding the highest correlated columns with the SalePrice
corr_matrix = house_prices.corr().abs()

# %%
corr_matrix['SalePrice'].sort_values(ascending=False)
# Out:
# SalePrice        1.000000
# OverallQual      0.790982
# GrLivArea        0.708624
# GarageCars       0.640409
# GarageArea       0.623431
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# FullBath         0.560664
# TotRmsAbvGrd     0.533723
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# GarageYrBlt      0.486362
# MasVnrArea       0.477493
# Fireplaces       0.466929
# BsmtFinSF1       0.386420
# LotFrontage      0.351799
# WoodDeckSF       0.324413
# 2ndFlrSF         0.319334
# OpenPorchSF      0.315856
# HalfBath         0.284108
# LotArea          0.263843
# BsmtFullBath     0.227122
# BsmtUnfSF        0.214479
# BedroomAbvGr     0.168213
# KitchenAbvGr     0.135907
# EnclosedPorch    0.128578
# ScreenPorch      0.111447
# PoolArea         0.092404
# MSSubClass       0.084284
# OverallCond      0.077856
# MoSold           0.046432
# 3SsnPorch        0.044584
# YrSold           0.028923
# LowQualFinSF     0.025606
# MiscVal          0.021190
# ...

# %%
#the columns with highest corr
#we will use it in our first regression with train-test split of 0.5

predictors = list(corr_matrix['SalePrice'].sort_values(ascending=False).index[1:11])
predictors
# Out:
# ['OverallQual',
#  'GrLivArea',
#  'GarageCars',
#  'GarageArea',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  'FullBath',
#  'TotRmsAbvGrd',
#  'YearBuilt',
#  'YearRemodAdd']

# %%
X_train, X_test, y_train, y_test = train_test_split(df[predictors], y, 
                                            test_size=0.1, random_state=8)

lr = LinearRegression()

lr.fit(X_train, y_train)

#A simple validation for our model
lr.score(X_test, y_test)
# Out:
# 0.8390424846976372

# %%
#same results can be achieved using the metrics funcion for computing R2. Here it shows what is actually compared.
metrics.r2_score( y_test, lr.predict(X_test))
# Out:
# 0.8390424846976372

# %%
#k-Fold cross-validation for the test set
kf = KFold(n_splits=folds,shuffle=True,random_state=1)
# Perform cross-validation and compute the mean of its results. The resulted R2 is used to compare different models. 
# We caoudl instead just use the whole test set to compute R2, but it would not reflect the performance of our model accurately. 
# The purpose of cross-validation is model checking not model building.
np.mean(cross_val_score(lr, X_test, y_test, cv=kf))
# Out:
# 0.7811985021461925

# %%
#surprisingly when we run the k-fold cross-validation on the whole set, it resutlts in realistic non-overfitting R2.
#It can be called when R2 is nearly =1.
np.mean(cross_val_score(lr, df[predictors], y, cv=kf))
# Out:
# 0.7468723936299566

# %%
#standardise your predictor matrices
ss = StandardScaler()
ss.fit(X_train)
X_train_ss = ss.transform(X_train)
X_test_ss = ss.transform(X_test)
# Out:
# /home/M/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/M/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   after removing the cwd from sys.path.
# /home/M/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   """

# %%
#A model using the scaled data
lr_scaled = LinearRegression()
lr.fit(X_train_ss, y_train)
#A simple validation for our model
lr.score(X_test_ss, y_test)
# Out:
# 0.8390424846976376

# %%
#cross validation on the scaled data
#The results is the same as the non scaled inouts
kf = KFold(n_splits=folds,shuffle=True,random_state=1)
np.mean(cross_val_score(lr_scaled, df[predictors], y, cv=kf))
# Out:
# 0.7468723936299566

# %%
#Gradient Descent

# %%
df_test = house_test[predictors]

# %% [markdown]
# # Final: Predicting the SalePrice for the test data

# %%
df_test[df_test.isnull().any(axis=1)]
# Out:
#       OverallQual  GrLivArea  GarageCars  GarageArea  TotalBsmtSF  1stFlrSF  \
# Id
# 2121            4        896         1.0       280.0          NaN       896
# 2577            5       1828         NaN         NaN        859.0       942
#
#       FullBath  TotRmsAbvGrd  YearBuilt  YearRemodAdd
# Id
# 2121         1             4       1946          1950
# 2577         2             6       1923          1999

# %%
df_test.fillna(0,inplace=True)
# Out:
# /home/M/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:4034: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   downcast=downcast, **kwargs)

# %%
X_train.shape, df_test.shape
# Out:
# ((1314, 10), (1459, 10))

# %%
predctions_test = pd.DataFrame(lr.predict(df_test), index=df_test.index)

# %%
predctions_test.to_csv( ')

# %%
predctions_test
# Out:
#                  0
# Id
# 1461  6.700323e+07
# 1462  8.362620e+07
# 1463  8.676859e+07
# 1464  8.609543e+07
# 1465  8.264472e+07
# 1466  8.499898e+07
# 1467  7.859607e+07
# 1468  8.035160e+07
# 1469  8.471395e+07
# 1470  6.621371e+07
# 1471  8.558519e+07
# 1472  6.282216e+07
# 1473  6.626195e+07
# 1474  8.080907e+07
# 1475  6.402826e+07
# 1476  1.156878e+08
# 1477  9.435356e+07
# 1478  1.002161e+08
# 1479  1.050776e+08
# 1480  1.421455e+08
# 1481  1.143762e+08
# 1482  8.643110e+07
# 1483  8.438750e+07
# 1484  7.723197e+07
# 1485  7.451999e+07
# 1486  8.839559e+07
# 1487  1.200749e+08
# 1488  9.637549e+07
# 1489  8.075267e+07
# 1490  9.040750e+07
# ...            ...
# 2890  5.543226e+07
# 2891  8.675688e+07
# 2892  5.253991e+07
# 2893  7.748208e+07
# 2894  5.858777e+07
# 2895  1.012117e+08
# 2896  9.719545e+07
# 2897  9.645536e+07
# 2898  9.810318e+07
# 2899  9.124710e+07
# 2900  7.889473e+07
# 2901  9.687974e+07
# 2902  8.740497e+07
# 2903  1.088206e+08
# 2904  1.057596e+08
# ...
